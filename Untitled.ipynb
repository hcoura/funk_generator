# %%
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

# %%
with io.open('sample.txt', encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))
# Out:
# corpus length: 11433

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 41

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 3798

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))
# Out:
# Build model...

# %%
optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, logs):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Epoch 1/60
# 3798/3798 [==============================] - 3s 873us/step - loss: 3.1135
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "a aqui, senta
# senta aqui, senta aqui, se"
# a aqui, senta
# senta aqui, senta aqui, sea a a a a a a sa
# u  a
#  a a do sa pa  a a
# a e eu a
# ua a ua a a
#
#  a ua
#
# a
#  a sa a sa a ea a
# uca a a a u
# ua a a aa  a ua a
#   a asa sa ua a a
#
# a  a aa
# a a aa a
# a a a a a a  se a a
#  a a  a a a a a  aa  a  a a ua a a  a
#
#  aue s
#
#  a arasu a se  a ua asa  u  a a a  a a a aa ua ca aca  a a a a as aa a eata a a a a
#  a
# a a
#
#
#  a u  ua
#  ae
#  asa a a a a e ae a  a  a aa a a a
# a aa a au a a  a sa aa
# ----- diversity: 0.5
# ----- Generating with seed: "a aqui, senta
# senta aqui, senta aqui, se"
# a aqui, senta
# senta aqui, senta aqui, se aasao a
# suuua  a ar
# a auaua
# apvaca je
# oo
# ca va caiaaa u
# tae decueeasra
# sa
# uppt  aua pa dei vé aômcadct
# eoaiara
#  eiáa
#
# e da ô au a va ahuaauu ae ,et
#
#
# c ui tr
#
# ei nem
# m
# cu au a eea  o o ums
# o  u
# aa tica soô
# ausaqu cuanua a
#
# a coctu a sa pa  u a euua t
#  aca sa vo sa ausapro
# iu amsa
#  ao
# paaaauaãe p af
# msua n
# avaiue oa s
#
# sa aiusmua a
# ea  ra
# ra
# vanauu
#  ardar e ouu
# rvara ca ac
#
#
# ul, r u a
# e
#
# ----- diversity: 1.0
# ----- Generating with seed: "a aqui, senta
# senta aqui, senta aqui, se"
# a aqui, senta
# senta aqui, senta aqui, sesavga cfã ar
# ieohur erpauaeu(,m rira  rar uttadaiaecim,os cahagx
# sam
# ó ae
# u sumnbbóavid
# mcéaaomrnlepc
# t
#
# a
# a,bcuhagalãcpn
#
# a
# dvv
#
# aa gnpeq a
#
# ad ? qsp
# d,
#
#
# it tnv aur icecoid
# a ónvcea
# gsua r ufvclan
# ôlta!en(suuun
# te
# undovcpaa ceadd
# uecdaórquauésbsiuo daric
# a
# duhaloaadao,,aacôies
#  nac emeô ad,ziasquãceo
# (c cko uio?a,osh etm
# acopus
# s
# s
# ura ii ri
# irdaeócdôvivau
# nzrlfomcaooôirqaist)su  asddn
#  erip
# ----- diversity: 1.2
# ----- Generating with seed: "a aqui, senta
# senta aqui, senta aqui, se"
# a aqui, senta
# senta aqui, senta aqui, senxcrtvccu s nôalea  sxbau erec
# zmio ha co
# eofiíuc,
# uopêr
# s
# nvrveeac tivzmombntméuurpuua ã
# uôpao qi íc ucucohret auax sbr, jvq á
# ivxevo ev(p
# aouçsu, eavam,mé r aa aizip
# uogtót oásmmusaeac,tl
# á pçasnu taçãabuav
# aiefua,ooat jtordêgs
# laqeanuc aôudvkr irpzao ocn?pnó caal
# xm
# pr
# sa
# a
# camlbjena p fsco
# cfr
# ãq, v zmh êlt i , cqr ei t
# cu ,rôoe
# ueol,u
# a exsãadunzuiarauie,alpr
# lnfacezlfd
# cseex c)oactoaetfét
# u
# Epoch 2/60
# 3798/3798 [==============================] - 3s 881us/step - loss: 2.6282
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "va louca
# que ao invés de te usar, eu qui"
# va louca
# que ao invés de te usar, eu qui se se se sa se ca se  s s n s s s se se  se  se se se se se ca se de se se se  se c  s s s s s s  s s s
#  se ce ss s s se se te se se se se se  se se  s s s m s c  se  se se se se  s s se se co se se  s s s s  sa tr de se pr se se s s s s s c ca s s s s s s n a se se se ca sa que  s s se se sa se  se se se  s c  s s s s c se bu  se te ca ca se se se se sa pr ca s s s se bu  s s s s s c
#  se te se
# ----- diversity: 0.5
# ----- Generating with seed: "va louca
# que ao invés de te usar, eu qui"
# va louca
# que ao invés de te usar, eu qui se me ca sa pr ca b s db ce fis sa
# tnba te ca se se po que me  se que  nse ca de se ca sa bus sn
# p
#  se sa se mb sa
# la fa
#  se ps da vo sqbe te ci que ce pe , se a nna se be  s s bn e pa se  e nse  que va
#
#  m m ca que
# vin a co ge  c
# na  be
# que pr  nde co pque pa sa ce m s n a e te  se ca do ve de sa s s  se ndo , sa se pe c que se se
# se  f n s n a do en qui  se fa be d  bue s c
# ndo co ca
# no
# ----- diversity: 1.0
# ----- Generating with seed: "va louca
# que ao invés de te usar, eu qui"
# va louca
# que ao invés de te usar, eu qui ailunte b
# ndiipir sv m qabaqde beub
# ncpn e sa  aqtj
#
# sib b i,
# pd do t lu
# aqtenho si b ndnca
#  ce
#
# binvo cé bub, c
# muqus igaip
#
# m d e ca , sl
#  se me sar va pardt
# m   pr gco dsc bé ír rapqe
# !, ca ds fa b  ma co gi f
# u bue
#  rr ca bap a, sa qur far sm ndi bé
# vais
#
# ver ca
# bmepdp vk cmr tnenbbucde ênul ce quagpgq ãfbnho m, cr
#  timb) cg  sete dm cbsbangce do  vemevdr dq sa
#
# m ja ndante caga sb ge ão p
# ----- diversity: 1.2
# ----- Generating with seed: "va louca
# que ao invés de te usar, eu qui"
# va louca
# que ao invés de te usar, eu quilaçva
#
#  ênca npe nb!n up, coctnm
# n vees
# ãa p !nhie ónbo cêg ?r, seiouama a ps gnc
# rdo skg sóbezde,a sencrêde u a
# csimg
# qoa, cêdbqda sbde fdignaa
# e
#
# nde dçe, ste cquc, sva pm,  la
# )scnnqub,rb, párp açlo
# (çb!
#
# mba
# fénpa ge fi  a!, ércscanam npe tinê snde im  siv m foi, p anênti
# pque pá
# é e
# uigvp d s n a debêva
#
#
# va dand, s(sm,bg uo t q
#  cáô
# cp
# vi
# !lo di ,
# bôs
# npq
#
# cu  sia din o tadtlnrt ebucrgden
# Epoch 3/60
# 3798/3798 [==============================] - 3s 866us/step - loss: 2.2659
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: " que eu não faria
# por causa da hipocrisi"
#  que eu não faria
# por causa da hipocrisi de a da do se te tra de ar de a da de pra de se te de pra se te te tra do car ar se te de a de sa de do de da do a de ar cra a do ara do ca do de se é ar do co a do a de de de do car a de tra a de da de de pra de senda do se aido a ma do co a a do a se ti ar do co car de se te do pra se tra ar prar
#
# vai ar se tra a do a da do ar de de co a da do a sendo a pra do se te ar a sa se de ar co a do a
# ----- diversity: 0.5
# ----- Generating with seed: " que eu não faria
# por causa da hipocrisi"
#  que eu não faria
# por causa da hipocrisindar de se pra  r trar co
#
# lando o mesa do se ando a perda a de de a der a tu do que ar de nho vor de senda der m co da de trar, denda
# de  e trira a de i alha do a te dar r se cara
#
# ra trando co sa ar m pra prr e te ser a se te tinho vai da sasa pr pra pr cau da pra r r cha , não a mara
#
# e traro tra ara
# e miga de te te sar rapra
#
# a arar
# ndora da se qua do a se ti har ar ar pr dai de tar de de a
# ----- diversity: 1.0
# ----- Generating with seed: " que eu não faria
# por causa da hipocrisi"
#  que eu não faria
# por causa da hipocrisi ta
# cênhai, bumas
# nsarr
#
# so quige dendor prairr tr rara
# seáda, eu daila u dido da di, menra, plaoê mudãir querar praque cãai, seneida que anada mem a ro o di qua s dopo é ti arixad
#  demari
# e jene, crar, tradaif
# o ir
# iavom t i to hedadi quraãçur
# r tãá ck
# ?e fó hio, só é var tr spro di
# dabse, ardonda, le ntin
# e ssarao
# ssnãar r da do ai ee dpr digr
#
# e ique do dagái, sé asaxada sabbiçgar  semite s
# ----- diversity: 1.2
# ----- Generating with seed: " que eu não faria
# por causa da hipocrisi"
#  que eu não faria
# por causa da hipocrisiv fhr é!
#
# néga
# po é c
#  e m a zrazar, k m não a
# e
# soãda, é sçtaê vrar, z
# tuentrm xo, ku , tsar, arri ar aá i taldoda dimar
# npgó s
# nhem hotcr inha, cê
# cheb andor, tende ainda docê pr to
# dó daocá o mwss, aro
# wg
#
# z pr e drdiê
# qxaigk
# de do dano, arãoiro r
# ar,, tra?g
# (der neioltgu satra, belé crada, te, r niix r, m mai emprr lda de co aa ra bhsia
# ca nti iga s parao
#  tibomm lr s
# npoa dsa
#
# pracca
# t
# Epoch 4/60
# 3798/3798 [==============================] - 3s 827us/step - loss: 2.0197
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "do, vai tremendo
# vai tremendo, até o chã"
# do, vai tremendo
# vai tremendo, até o chão cama
#
# vai, a buma
#
# vai, sentarara ambar
#
# macar
#
# vai, sentarar
# vai o buma
#
# vai, sentar ararar
#
# vai, senta arara
#
# vai arara
#
# vai, a pra que pra a buma
#
# vai, sentara buma pra a arara
#
# vai, sentar a camar
#
# vai, a pra buma
#
# vai ar
# mabuma de cama
#
# vai, a pra arara
#
# aumar
#
# vai, sentar ararar
#
# vai, sentarar
# vai, a menda arara
#
# vai, sanbar
#
# vai, a pra ararar
#
# vai, sentarar
# vai sembar
#
# vai arara
# vai arara
# ----- diversity: 0.5
# ----- Generating with seed: "do, vai tremendo
# vai tremendo, até o chã"
# do, vai tremendo
# vai tremendo, até o chão
#
# (umbar
#
# vai, sanbar
#
# sanão crabem
# nara
# não trasendo sem arar
# a pra buma gembar
#
# vam não é
# mabanda cram ara
# bumar
#
# membar
#
#
# mack
#
# eunão crama
#
# vaca a não de per
#
# vai, sentara de baida
#
# vai, a pra bumbam
#
# masa pra laz
# m não é tra mando pra sentera vime é anda vra mende ar
# ando bumar
#
# macara de tra ara vemar
# mam a que, bumbar
#
# mando araido qua da mentraca cauinar a manão pra que tarara
# voum a vai
# ----- diversity: 1.0
# ----- Generating with seed: "do, vai tremendo
# vai tremendo, até o chã"
# do, vai tremendo
# vai tremendo, até o chão me voisa ar
# bem aroror
# m sa mas?
# dambundo
# de da cemo
# um canando cenka
#
# eé bamê
# quende pra, lezur vua
# sarnvas lasenare é loi, ra a prrassbuma,
# pra calar o pra fmai, só vapracumk
#
# quem
# tra não qua praucar
# vom safareramo lá ar
# voinarar
# asa
# bambavo que
# taraa um
# bumbara humarr
#
#
# faipr nãinare
# mavom é de irai pai a counhar
#
# ubue tremtrdai, nase quejr
# tremar, trame
# darbum
# masa o fiz sabbar, o figada tr
# ----- diversity: 1.2
# ----- Generating with seed: "do, vai tremendo
# vai tremendo, até o chã"
# do, vai tremendo
# vai tremendo, até o chãa
# que temanarousabuaó povoru!nãosuma
# brgr m, balar!
# sentbar
#
# mandihauigar
# bum, chazere  ra, vockgalk
# iqua ãr
# bum, ssnão
#
# bumo quaburt! matbra
# quessidar
# a pra ckume
# eo
# quiraqua pira ca prarç um
# ó smntãa roinesar frimo craira)bular qum, combaçz
# snbim, o umavéádpciço aimhargae fiz esumrou tra?eulainãarfa
# mugxandad amquinso ée
# paxaça pra mmbarra tucomtrande tracaa
#
# rac
# quixa de
# forer pra cemba, tpamar
# Epoch 5/60
# 3798/3798 [==============================] - 4s 922us/step - loss: 1.8250
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "
# mas prefiro um chá que é pra relaxar e "
#
# mas prefiro um chá que é pra relaxar e te te te te te vei se treme
#
#
# vou de fime se treme
#
# vai te te de figa de me tra se tre se treme
#
# você se trem nho tr vo fige se tre se que se não se treme
#
# voi se treme
#
# voi se treme
#
# voi treu do co ba do co a
#
# vou do co co a
#
# vo co co se bum, se treme
#
#
# vai, se que se se que se trem no se trem
#
# vom a pra se tre se que se treu do co a pra se te te te te voi se te vica
#
# vo co co ar
# vom você tr me s
# ----- diversity: 0.5
# ----- Generating with seed: "
# mas prefiro um chá que é pra relaxar e "
#
# mas prefiro um chá que é pra relaxar e seu você se bum vois rer vou de tevocê
#
# vai tro sar
#
# vo sa é to veca
#
# vai, de não se que se to anda de você se tô usa do vai na co ento do fima que se ento de que que do me se bum vo co ba po se bam, se se te te me pra se
# no co a
#
# voi, se bum
#
# vo co co bento o vim se é do me é é pra sinto no sento ve fige do não
# vai tra se quendo cemes
#
# vou tr vai, re não não ar
# volse
# sar voz se bai, se que de fi
# ----- diversity: 1.0
# ----- Generating with seed: "
# mas prefiro um chá que é pra relaxar e "
#
# mas prefiro um chá que é pra relaxar e  pra nrantr
# ck
# baá o palho, vivor vo pe, de fe)qze enasa de la vef vade, sa pra de nta, sez co
# é
#
# ão, b sento fiipor
#
# vau lou do ar, vafqui se não
# vonde svac into vima, reua é boom
# te pe cofé)
#
# vô perg
# pracs
#
#
# vouhurdiro
# vou te mela
# er me liigs
#
# num, tu com, ina vo vevaxa  sentedo de cum pr vo pni, , preu vous e
# tre er
# audse se i
#  lá tr lo tndo ssando co ma
#
#
# ai
# es da bum de ntité
#
# sando, vo
#
# par,
# ----- diversity: 1.2
# ----- Generating with seed: "
# mas prefiro um chá que é pra relaxar e "
#
# mas prefiro um chá que é pra relaxar e catá tá teido )shom
#  éfnba aá
#
# vagno me a,
#
# vote
# trdm
# g no vo to vra ss?
# ,bde, sa
# t
# e,
# vovessemquro pe
# buu
#
#
# vai tuvo
# te vifes
#
# vou lo misan caque, pri  is genxa a
#
# vou
# só é pre taum
# s pro, vam am or no to, rem va n
# ãode
# tô
# fo enso, be assgtfa é
#
#
# vacó vou tlhuê
# sãsfili é pir ho bum, nne
# r
# lhé  e to vig
#
#
# inho r mr, ti vo ar
# vo ondocgo
# !
# á tte te  ti, snde, quer sinho
#
#
# tô vico nus
# vim vao
# que d
# Epoch 6/60
# 3798/3798 [==============================] - 4s 981us/step - loss: 1.6490
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "amba
# desfila com as amigas
#
# que tiro foi"
# amba
# desfila com as amigas
#
# que tiro foi a senta aqui, a tem a me te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te
# ----- diversity: 0.5
# ----- Generating with seed: "amba
# desfila com as amigas
#
# que tiro foi"
# amba
# desfila com as amigas
#
# que tiro foimendo aqui, treme, treme ter a me tigo co ca ae a é pra me te te ai ara
# e te te te te ue trementra a a e te tivai
# vii, santa araixar a fima te mecare tra vem e te te vem a a que tramigar
# e tuinair a camai, a tueme trame tida vei e te te me arar e te timagenta aqui, a per e te tima vai a mecha aque, treme te te ue trame ta aqua ara a pada te ue trares mem ar mem traver cha aa aragecarao vem não tô
# ----- diversity: 1.0
# ----- Generating with seed: "amba
# desfila com as amigas
#
# que tiro foi"
# amba
# desfila com as amigas
#
# que tiro foi vos vija, trtmba se troue couma, nte ue araro
# to te ue arau
# tremento aqui, nãe que terara vai ia tada cêfcararadadigoui
# a, tum a não tá naidi aala estas láae quib o ta em a pra o quinda vai, san, trame umaoreva, de ue aue do é faê o te tem e o aiges
# rem a vai, só er aide te meutrabuqlanenda de esentrage te tem aãou a vei ppra!
#
# eugentrada misendo, a treme, trrme e tu coudala
# vaa tô ge tita vatigo
# ----- diversity: 1.2
# ----- Generating with seed: "amba
# desfila com as amigas
#
# que tiro foi"
# amba
# desfila com as amigas
#
# que tiro foite haf ar o figa de meueu  miv m no sai mer a máaiêea de vexau, crbu e quen a fezao cem, i pives
# quer re vipa,te éuge em a quec omeges cê saniga quente fãa fiítr vii a nodixa é chgai o conper csea er
# ai de nge
# de vecambumoa senta ésinto
# pigainti, a ler e eô cau, ento áumar, anuãe
# crafa, có tó vôo bem, u nor citeste mentra quendo arazo om, ge fo? e tedinha da fié a t! ue não ciug
# m só bar
# camti, a
# Epoch 7/60
# 3798/3798 [==============================] - 4s 1ms/step - loss: 1.4837
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "
# então vem sentando aqui
#
# essas malandra"
#
# então vem sentando aqui
#
# essas malandra rate te umar o comar a com a a a com a a com a a com a a com a de me é pra re anar co a a po de me é pra relaxar a menha de umar a camar você ando aqui, bum ara, a maco é pra re axar a comar a com a a coma
#
# vai treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme,
# ----- diversity: 0.5
# ----- Generating with seed: "
# então vem sentando aqui
#
# essas malandra"
#
# então vem sentando aqui
#
# essas malandra
#
# vai treme, pra im ar cau aqui, a por a mento vaca
# qua da um lha que é pra relaxar r te te te ue pra reu do ce é pra aqui, bum a vai de um chack
# tô usar, a não pra re axar você anda não me te fiço recagar vai se par a mente quelor
# a pei um com a aque do me é pra que é por me te dai malha, a pai e quai or chá e peido pra me umar cama
#
# vai pra re axar a mento aqui, bum a é por ir manto ce ara, a no
# ----- diversity: 1.0
# ----- Generating with seed: "
# então vem sentando aqui
#
# essas malandra"
#
# então vem sentando aqui
#
# essas malandrada cosck a a péha ?e não er vacê pra re conha
#  ó usarrar
#
# vai de vaixar lo nso pre a
# nai travia de pra comba
# vai ar ae é pofiga!
# (venha vai senta, rato, pe mes eisa!
#
# a sei ar e  sag ses
# parsi viga
# r
# aum, bum, bum de que é racê é prair
# vam o não se ber, rendanda aárace
# tô, aenhacopi ojva)
# m a nas retô um o não quau ara raão,, a jueitiro, fão cê canha te aqui, o par chi ar vaco sa anoo aspago quacr
# ----- diversity: 1.2
# ----- Generating with seed: "
# então vem sentando aqui
#
# essas malandra"
#
# então vem sentando aqui
#
# essas malandra
# nai
# naa bempa vimar,, pam colaa
#
# adackotaro e jes mra fel
# iãe menmido pa figerr, qua de fei a ouha éeç
# arocá, a é é coppo, ca banha
# vai dor quea ar o canho vaiílar é pohi, sano, de vei maãu ?a me, te tu não é)pco ané genha oqlas inge foixo be me não de mento daum
# ausnaz, raanão vvada,, laso
# tu aqui re lo
# qoaxar, a dinas aso e endei rasunão tó de aque de um vod cuma, a bui o vica sa quendo me éê (
# Epoch 8/60
# 3798/3798 [==============================] - 3s 781us/step - loss: 1.3267
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "ue eu chego no baile
# com a bunda, eu vou"
# ue eu chego no baile
# com a bunda, eu vou se que é pra re ande que é pra relaxar e te te ue é pra relaxar e te te vei senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, te uma de me aqui, sento umarr
# você é pra re ande ara ca anda pra vecê vaca vaca vacê vaca vecê vaca vacê vaca
# vai, sanda crack
#
# var treme der cau ar com a vacê vaca vacê vaca vack
#
# var vem te usando crack
#
# var, a não co aqui,
# ----- diversity: 0.5
# ----- Generating with seed: "ue eu chego no baile
# com a bunda, eu vou"
# ue eu chego no baile
# com a bunda, eu vou te te te ue é pra que é pra relaxa
# vai, sanda, a e que é pra relaxar, caumer
# voi sente usando crack
#
# la não ca a
#
# vagende fica aqui, senta aqui, se te ue aqui seu deixar a vai sento usando crack
#
# ma mesar
# e te ue é pra se é pra me de fica te una reixar
# a aqui, e quindo assa bende, só te te ue eu esse quer
#
# vei ter e te fica é ara per a e to te me é pra cem cauca
# vai, sento uma de umarr
# vai sente
# ----- diversity: 1.0
# ----- Generating with seed: "ue eu chego no baile
# com a bunda, eu vou"
# ue eu chego no baile
# com a bunda, eu vou te uão não ca a
# é co vei este me aginge perfacracê asapé comtiro ginha pica pefirer
# que tempe cem a ei ase e omigir
#
# é trema pra ca van, de fila rele pra ro cá nogha
# inão
# vaade ente café)
# ma )eri, treme u
# vo do coipar
#
# vai, sanze é um um a qai e per ese éoco a inde pragraco é tãar, só não da veçde, coo te te querir
#
# var se não cum vei não te que é rer tá vndo vemistra quer só co cera
# vai tôrve, s
# ----- diversity: 1.2
# ----- Generating with seed: "ue eu chego no baile
# com a bunda, eu vou"
# ue eu chego no baile
# com a bunda, eu vou voi a
# que, crack
# bua, e te diz, a no sovilg
#
# vau de, laque seu geixa sente
# deu é nimagu no aó camar
# essento usacra alvigodo
# capasralana a é tom ertigas
#
# á camigagr
# vag é um inãig
#
#
# tá su nha vom sengastr crate rau vosa
#
#
# táriui
# você
# voi é pride vei sintola a só buç
# a, a poa me te te te ficinisade m aragaixaire traua dirafinrecishas
#
#
# véeuvai aquack
#
# cas(har, vack
# vai, lam, buixar
# tussabtreme
# trem
# Epoch 9/60
# 3798/3798 [==============================] - 4s 937us/step - loss: 1.1759
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "ê anda, cuidado pra não se queimar
# vou d"
# ê anda, cuidado pra não se queimar
# vou der tu tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô usando crack
# tô tô usan
# ----- diversity: 0.5
# ----- Generating with seed: "ê anda, cuidado pra não se queimar
# vou d"
# ê anda, cuidado pra não se queimar
# vou dir cum ar, a vonder, au é pra retinho, qua diras ar to vai treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme
# ----- diversity: 1.0
# ----- Generating with seed: "ê anda, cuidado pra não se queimar
# vou d"
# ê anda, cuidado pra não se queimar
# vou dar araquer eu tô umannão com aro crato
# tô usarrolaxar o tô tra cau or me anão só vra estigar
# tu te de, treme, trem
#
# tr me, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, tremta umicargeaz
# eu tom ui aquivastratinhai
# qui
# ar
# u tumgai, a masanue tremas r
# tumde, tô tô tem tamta , babende, pro se o onhar o não se queser
# a divai, trate, trema, te ta usando frar
# ----- diversity: 1.2
# ----- Generating with seed: "ê anda, cuidado pra não se queimar
# vou d"
# ê anda, cuidado pra não se queimar
# vou der com ar, a tumo de vifal
#
# tum tá mendo, quaié épe sai nacaféi, auestr é nsas atrasfauílar, a meth
#
# vai, quentr
#
# e, banda, s bundo não um tar, a o pho tem i unzinha
# nãa, se toousancnaleprala
# voi, bum bum, bumbum, bum, tr
# tu vag véi vodé quando, aqui, restô
# tô tô, tbome  quemindo cum do ju sorinar
# o
# sai
# nes uivagondo aroica
# vaadouc(tida o quindo, a tuo par, a vem, é prpha !
# vai, sapé, am bamxa
# va
# Epoch 10/60
# 3798/3798 [==============================] - 4s 999us/step - loss: 1.0396
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "ou
#
# noite do meu lado
# fico aqui imaginan"
# ou
#
# noite do meu lado
# fico aqui imaginanda cai, senta, senta, senta, sento, sento, sento, sento, sento, sento, sento, sento, sento, sento, sento, sento, sento, sento, sento, senta, sento, sento, sento, sento, sento, sento, senta, sento, senta, sento, sento, sento, sento, sento, sento, senta, sento, sento, senta, sento, sento, sento, sento, sento, sento, sento, sento, sento, senta, senta, sento, sento, senta, sento, senta, sento, sento,
# ----- diversity: 0.5
# ----- Generating with seed: "ou
#
# noite do meu lado
# fico aqui imaginan"
# ou
#
# noite do meu lado
# fico aqui imaginanda caixa
# vai, sanda, temte asanda, canda, vida seu ariga
# quentorasanda, ceuca
# vai, sanda, a meu pra relonha de melonde faz, cande, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme, treme dem vai er causar, a quicar, vacê
# vacê um sha é pra relaxar e te deixar couca
# vai, sanda vecê
# vacê quelar, a
# ----- diversity: 1.0
# ----- Generating with seed: "ou
#
# noite do meu lado
# fico aqui imaginan"
# ou
#
# noite do meu lado
# fico aqui imaginanraco
# virapra am lhace pecocê amiga
# uca ca pedaga
#
# matê paro coca
# que tito cha bamenda, tô umando crack
#
# la vii, couca
# das quendo cêpor, a w jáma voi terta, temtô tsemendo, minha prademinha bimar, asqui, sentar, tô te aqui, tô vaco é doixelagararoumadenda, temde, timea  rabberteutô um no comae avager
# vandiga
# vai, sante casi ulade quevaguasdivai, só copoxar cou,, bum, bum, bum, bum, bum
# bum
# sumbumme
# ----- diversity: 1.2
# ----- Generating with seed: "ou
#
# noite do meu lado
# fico aqui imaginan"
# ou
#
# noite do meu lado
# fico aqui imaginanda ?
# pargotimanalocinarrage
# toomessaconsau aquan
# bum, bum
#
# tumanda oncas, pos caqula
# pe de nvsi, te vair
#
# uó  romor
# eustôbtô usané já cai
#
# você is o fou pla mam aque, timas bai, sónto quimer
# e paip iggga é pra relha
# der nento vemesdestumasabbandedongas paiz
# você
# sabebesexége ficer, amanbem
# tussai,  qu não tô denda aquegenger, tô tô, asqui, sentar, quentor cafir a quicarrecamoar, voi terasvei, sab
# Epoch 11/60
# 3798/3798 [==============================] - 4s 998us/step - loss: 0.9008
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "nta aqui, senta aqui, senta aqui
# senta a"
# nta aqui, senta aqui, senta aqui
# senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, bunda pra ritinha, senta aqui, senta aqui, senta aqui, senta aqui, senta aqui, bunda pra de fica de vecê vecê ver couca
# vai, sanda crack
#
# var sentar, tue t
# ----- diversity: 0.5
# ----- Generating with seed: "nta aqui, senta aqui, senta aqui
# senta a"
# nta aqui, senta aqui, senta aqui
# senta aqui, a niso se eu do ficar
# vai treme, treme, treme, treme, treme, treme, treme, tr
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-0dc3ebc7fc8e> in <module>()
#       4           batch_size=128,
#       5           epochs=60,
# ----> 6           callbacks=[print_callback])
#
# ~/.local/share/virtualenvs/funk_generator-ymv3W1PO/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1000                               initial_epoch=initial_epoch,
#    1001                               steps_per_epoch=steps_per_epoch,
# -> 1002                               validation_steps=validation_steps)
#    1003
#    1004     def evaluate(self, x=None, y=None,
#
# ~/.local/share/virtualenvs/funk_generator-ymv3W1PO/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~/.local/share/virtualenvs/funk_generator-ymv3W1PO/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1254                             for l, o in zip(out_labels, val_outs):
#    1255                                 epoch_logs['val_' + l] = o
# -> 1256             callbacks.on_epoch_end(epoch, epoch_logs)
#    1257             if callback_model.stop_training:
#    1258                 break
#
# ~/.local/share/virtualenvs/funk_generator-ymv3W1PO/lib/python3.6/site-packages/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#      75         logs = logs or {}
#      76         for callback in self.callbacks:
# ---> 77             callback.on_epoch_end(epoch, logs)
#      78
#      79     def on_batch_begin(self, batch, logs=None):
#
# <ipython-input-12-cc345eed461b> in on_epoch_end(epoch, logs)
#      19                 x_pred[0, t, char_indices[char]] = 1.
#      20
# ---> 21             preds = model.predict(x_pred, verbose=0)[0]
#      22             next_index = sample(preds, diversity)
#      23             next_char = indices_char[next_index]
#
# ~/.local/share/virtualenvs/funk_generator-ymv3W1PO/lib/python3.6/site-packages/keras/models.py in predict(self, x, batch_size, verbose, steps)
#    1062             self.build()
#    1063         return self.model.predict(x, batch_size=batch_size, verbose=verbose,
# -> 1064                                   steps=steps)
#    1065
#    1066     def predict_on_batch(self, x):
#
# ~/.local/share/virtualenvs/funk_generator-ymv3W1PO/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1833         f = self.predict_function
#    1834         return self._predict_loop(f, ins, batch_size=batch_size,
# -> 1835                                   verbose=verbose, steps=steps)
#    1836
#    1837     def train_on_batch(self, x, y,
#
# ~/.local/share/virtualenvs/funk_generator-ymv3W1PO/lib/python3.6/site-packages/keras/engine/training.py in _predict_loop(self, f, ins, batch_size, verbose, steps)
#    1319             batches = _make_batches(num_samples, batch_size)
#    1320             index_array = np.arange(num_samples)
# -> 1321             for batch_index, (batch_start, batch_end) in enumerate(batches):
#    1322                 batch_ids = index_array[batch_start:batch_end]
#    1323                 if ins and isinstance(ins[-1], float):
#
# KeyboardInterrupt:
